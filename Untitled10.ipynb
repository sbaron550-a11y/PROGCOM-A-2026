# %% [markdown]
# <a href="https://colab.research.google.com/github/sbaron550-a11y/PROGCOM-A-2026/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ESTRUCTURA WHILE - MIENTRAS
# No sabe cuántas veces se debe repetir la acción
#
# Sintaxis en python
#
#
# ```
# While (ci):
# parte del codigo a repetir
# modificador de CI
# ```
#
# **OJO!!**
# CI: La CI debe tener un valor de verdad VERDADERO (TRUE) para poder ingresar al while

# %% [markdown]
# Sintaxis en java
#
#
# ```
# While(CI){
#   Código que debe respetirse
#   Un modificador de CI
# }
# ```

# %%
#Piedra, papel o tijera
import random
yo=int(input("Elige entre 1.Piedra, 2.Papel, 3.Tijera"));

# %%
m=random.randint(1,3)
m
# Out:
# 3

# %%
if yo==m: print("empate. Ambos elegimos")
elif yo==1 and m==2: print("Perdiste. Máquina eligió")
elif yo==2 and m==3: print("Perdiste. Máquina eligió")
elif yo==3 and m==1: print("Perdiste. Máquina eligió")
else: print("Ganaste!!")
# Out:
# Ganaste!!

# %%
#Robusteciendo el codigo
while yo<1 or yo>3:
  yo==int(input("ese valor no es valido. Elije entre 1.Piedra, 2.papel, 3.tijera"))

# %%
#Piedra, papel o tijera
import random
yo= str(imput())
