# %% [markdown]
# <a href="https://colab.research.google.com/github/sbaron550-a11y/PROGCOM-A-2026/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crea un programa que muestre la tabla de multiplicar de un número hasta el 10.

# %%
num = int(input("Ingrese un número: "))
i = 1

while i <= 10:
    print(num, "x", i, "=", num * i)
    i += 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Escribe un programa que calcule la suma de números naturales hasta n.

# %%
n = int(input("Ingrese un número: "))
i = 1
suma = 0

while i <= n:
    suma += i
    i += 1

print("La suma es:", suma)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Desarrolla un programa que calcule el factorial de un número. Recuerda que el factorial de 0 es 1 y no existen factoriales negativos.

# %%
n = int(input("Ingrese un número: "))

if n < 0:
    print("No existen factoriales negativos")
else:
    i = 1
    factorial = 1
    while i <= n:
        factorial *= i
        i += 1

    print("El factorial es:", factorial)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Crea un programa que muestre los primeros n números de la serie Fibonacci.

# %%
n = int(input("¿Cuántos números Fibonacci desea?: "))

a = 0
b = 1
i = 0

while i < n:
    print(a)
    temp = a + b
    a = b
    b = temp
    i += 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Escribe un programa que adivine entre un conjunto de diez colores definidos por el usuario, con un máximo de 10 intentos.

# %%
color_correcto = input("Define el color secreto: ")

intentos = 0
max_intentos = 10
adivinado = False

while intentos < max_intentos and not adivinado:
    intento = input("Adivina el color: ")

    if intento == color_correcto:
        print("¡Correcto!")
        adivinado = True
    else:
        print("Incorrecto")

    intentos += 1

if not adivinado:
    print("Se acabaron los intentos")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Desarrolla un programa que muestre los números pares del 1 al 100.

# %%
i = 1

while i <= 100:
    if i % 2 == 0:
        print(i)
    i += 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Crea un programa que calcule la suma de los dígitos de un número.

# %%
num = int(input("Ingrese un número: "))
suma = 0

while num > 0:
    digito = num % 10
    suma += digito
    num //= 10

print("La suma de los dígitos es:", suma)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Escribe un programa que determine si un número es primo.

# %%
num = int(input("Ingrese un número: "))

i = 1
contador = 0

while i <= num:
    if num % i == 0:
        contador += 1
    i += 1

if contador == 2:
    print("Es primo")
else:
    print("No es primo")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Desarrolla un programa que muestre el patrón de un triángulo con asteriscos.

# %%
filas = int(input("Ingrese el número de filas: "))

i = 1

while i <= filas:
    j = 1
    while j <= i:
        print("*", end="")
        j += 1
    print()
    i += 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Crea un programa que calcule la potencia de un número sin usar el operador **.

# %%
base = int(input("Ingrese la base: "))
exponente = int(input("Ingrese el exponente: "))

resultado = 1
i = 0

while i < exponente:
    resultado *= base
    i += 1

print("Resultado:", resultado)
