# %% [markdown]
# <a href="https://colab.research.google.com/github/sbaron550-a11y/PROGCOM-A-2026/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1, 2, 3, 4, 5]

a.append("Hola")

a[2] = "Sneyder"
print(a)

[1, 2, 'Sneyder', 4, 5, 'Hola']
# Out:
# [1, 2, 'Sneyder', 4, 5, 'Hola']
# [1, 2, 'Sneyder', 4, 5, 'Hola']

# %% [markdown]
# #DICIONARIO
# 1. Tipo de dato como las listas.  **SI SON MUTABLES**
# 2. Se utilizan para almacenar datos en pares,
# clave:valor. La clave **DEBE SER ALFANUMÉRICA**
#
# ```
# variable={clave:valor}
# ```
# 3. Los diccionarios son colecciones ordenadas, modificables y **NO PERMITE DUPLICADOS**.

# %%
 estudiante= {"nombre": "SNEYDER",
                "ID": "U00187593",
                "Edad": 18,
                "Carrera": "Ingenieria industrial"}
 print(estudiante)
# Out:
# {'nombre': 'SNEYDER', 'ID': 'U00187593', 'Edad': 18, 'Carrera': 'Ingenieria industrial'}

# %%
galletas=["angelitos","diablitos","dinosaurios"]
galletas_precio=[20000,15000,25000]
galletas_cant=[3,5,10]

# %%
def menu_galletas():
  for i in range(3):
    print(f"{galletas[i]}:{galletas_precio[i]},cantidad:{galletas_cant[i]}")

# %%
menu_galletas()
# Out:
# angelitos:20000,cantidad:3
# diablitos:15000,cantidad:5
# dinosaurios:25000,cantidad:10

# %%
galletas
# Out:
# ['angelitos', 'diablitos', 'dinosaurios']

# %% [markdown]
# ##Impresión de elementos en un diccionario
#
# 1. Si quiero imprimir todos los elementos de una clave
#
# ````
# print(diccionario[clave])
# ````
# 2. Quiero imprimir las claves
#
# ````
# print(diccionario.keys)
# ````
# 3. Ingresando a un elemento particular del valor

# %%
galleta["cantidad"]

# %%
galleta["tipo de galleta"]

# %%
galleta.keys()

# %%
galleta["precio"][1]

# %%
#Diccionarios
galleta={"tipo de galleta":["angelitos","diablitos","dinosaurios"], "precio":[20000,15000,25000], "cantidad":[3,5,10]}

# %%
def menu_galleta_dict():
  for i in range(3):
    print(f"{galleta["tipo de galleta"][i]}:{galleta["precio"][i]}, cantidad:{galleta["cantidad"][i]}")

# %%
menu_galleta_dict()
