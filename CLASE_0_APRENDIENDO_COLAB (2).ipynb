# %% [markdown]
# #título
# ##título
# ###título

# %% [markdown]
# #Bienvenida

# %% [markdown]
# ##aprendiendo a usar print
# print() es un metodo que permite imprimir informacion en consola
#
#
#
# ```
# if (condicion) ==verdadera
# print ("Pasan cositas")
# else:
# print ("Pasan otras cositas")
# ```
# El print0 puede imprimir lo siguiente:
# 1. Cualquier tipo de dato
# 2. Cualquier método o función (su dirección en memoria)
# 3. Concatenación de texto
# 4. Operaciones matemáticas

# %% [markdown]
# ###Conociendo el imput
# input() es un metodo con triple función
#
#
# *   Declara: toda la información que ingresa cn este metodo, se declara    automaticamente como string (caracter).
# *   lee: porque almacena una variable
# *   imprime

# %% [markdown]
# ###concatenación

# %%
x=int(input("ingrese su edad : "))
y=input("ingrese su nombre: ")
# Out:
# ingrese su edad : 18
# ingrese su nombre: santiago

# %%
#ejemplo 1
print(y,"tiene una edad de",x)
# Out:
# santiago tiene una edad de 18

# %%
#ejemplo 2
print(y+" tiene una edad de "+str(x))
# Out:
# santiago tiene una edad de 18

# %%
#Ejemplo 3
print(f"{y} tiene una edad de {x}")
# Out:
# santiago tiene una edad de 18
